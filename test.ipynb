# %%
import numpy as np

# %%
a = np.array([0.3, 2.9, 2.0])
print(a)
print(np.exp(a))
print(np.sum(np.exp(a)))
# Out:
# [0.3 2.9 2. ]
# [ 1.34985881 18.17414537  7.3890561 ]
# 26.91306027594971

# %%
def softmax(x):
    c = np.max(x)
    exp_x = np.exp(x-c)
    
    print((exp_x) / np.sum(exp_x))
    return exp_x / np.sum(exp_x)
